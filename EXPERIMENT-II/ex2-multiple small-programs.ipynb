# %%
import pandas as pd
import numpy as np

np.random.seed(42)

data = {
    "Student_ID": range(1, 101),
    "Name": [f"Student_{i}" for i in range(1, 101)],
    "Age": np.random.randint(18, 26, 100),
    "Department": np.random.choice(["CSE", "ECE", "IT", "MECH", "CIVIL"], 100),
    "Marks": np.random.randint(40, 101, 100)
}

df = pd.DataFrame(data)

df.to_csv("students.csv", index=False)

print("Dataset Created Successfully")
# Out:
# Dataset Created Successfully

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df.head())
# Out:
#    Student_ID       Name  Age Department  Marks
# 0           1  Student_1   24        ECE     72
# 1           2  Student_2   21        ECE     90
# 2           3  Student_3   22       MECH     81
# 3           4  Student_4   24        ECE     83
# 4           5  Student_5   20        ECE     63

# %%
import pandas as pd

df = pd.read_csv("students.csv")

marks_series = df["Marks"]

print(marks_series)
# Out:
# 0     72
# 1     90
# 2     81
# 3     83
# 4     63
#       ..
# 95    70
# 96    69
# 97    81
# 98    74
# 99    46
# Name: Marks, Length: 100, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df)
# Out:
#     Student_ID         Name  Age Department  Marks
# 0            1    Student_1   24        ECE     72
# 1            2    Student_2   21        ECE     90
# 2            3    Student_3   22       MECH     81
# 3            4    Student_4   24        ECE     83
# 4            5    Student_5   20        ECE     63
# ..         ...          ...  ...        ...    ...
# 95          96   Student_96   23        CSE     70
# 96          97   Student_97   19         IT     69
# 97          98   Student_98   21         IT     81
# 98          99   Student_99   23        CSE     74
# 99         100  Student_100   22      CIVIL     46
#
# [100 rows x 5 columns]

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df.head())
print(df.tail())
# Out:
#    Student_ID       Name  Age Department  Marks
# 0           1  Student_1   24        ECE     72
# 1           2  Student_2   21        ECE     90
# 2           3  Student_3   22       MECH     81
# 3           4  Student_4   24        ECE     83
# 4           5  Student_5   20        ECE     63
#     Student_ID         Name  Age Department  Marks
# 95          96   Student_96   23        CSE     70
# 96          97   Student_97   19         IT     69
# 97          98   Student_98   21         IT     81
# 98          99   Student_99   23        CSE     74
# 99         100  Student_100   22      CIVIL     46

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df.info())
print(df.describe())
print("Shape:", df.shape)
print("Columns:", df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  100 non-null    int64
#  1   Name        100 non-null    object
#  2   Age         100 non-null    int64
#  3   Department  100 non-null    object
#  4   Marks       100 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.0+ KB
# None
#        Student_ID         Age       Marks
# count  100.000000  100.000000  100.000000
# mean    50.500000   21.600000   70.410000
# std     29.011492    2.146173   18.265768
# min      1.000000   18.000000   40.000000
# 25%     25.750000   20.000000   56.000000
# 50%     50.500000   21.000000   71.000000
# 75%     75.250000   23.000000   88.000000
# max    100.000000   25.000000   99.000000
# Shape: (100, 5)
# Columns: Index(['Student_ID', 'Name', 'Age', 'Department', 'Marks'], dtype='object')

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df[df["Marks"] > 80])
# Out:
#     Student_ID        Name  Age Department  Marks
# 1            2   Student_2   21        ECE     90
# 2            3   Student_3   22       MECH     81
# 3            4   Student_4   24        ECE     83
# 6            7   Student_7   22       MECH     98
# 7            8   Student_8   22        CSE     93
# 12          13  Student_13   20        ECE     91
# 13          14  Student_14   20        CSE     88
# 14          15  Student_15   25       MECH     88
# 15          16  Student_16   22       MECH     97
# 16          17  Student_17   21       MECH     91
# 21          22  Student_22   22        CSE     88
# 23          24  Student_24   25        CSE     88
# 24          25  Student_25   21        CSE     95
# 26          27  Student_27   23         IT     98
# 27          28  Student_28   19         IT     88
# 31          32  Student_32   18        CSE     93
# 39          40  Student_40   20       MECH     92
# 40          41  Student_41   20        ECE     83
# 45          46  Student_46   21         IT     94
# 47          48  Student_48   24        CSE     94
# 49          50  Student_50   23      CIVIL     95
# 50          51  Student_51   24         IT     98
# 55          56  Student_56   21        CSE     91
# 60          61  Student_61   20         IT     87
# 64          65  Student_65   24       MECH     99
# 65          66  Student_66   19      CIVIL     98
# 71          72  Student_72   19         IT     99
# 72          73  Student_73   18         IT     98
# 81          82  Student_82   21       MECH     91
# 91          92  Student_92   21         IT     96
# 93          94  Student_94   23       MECH     89
# 97          98  Student_98   21         IT     81

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df[["Name", "Department", "Marks"]])
# Out:
#            Name Department  Marks
# 0     Student_1        ECE     72
# 1     Student_2        ECE     90
# 2     Student_3       MECH     81
# 3     Student_4        ECE     83
# 4     Student_5        ECE     63
# ..          ...        ...    ...
# 95   Student_96        CSE     70
# 96   Student_97         IT     69
# 97   Student_98         IT     81
# 98   Student_99        CSE     74
# 99  Student_100      CIVIL     46
#
# [100 rows x 3 columns]

# %%
import pandas as pd

df = pd.read_csv("students.csv")

result = df[(df["Marks"] > 80) & (df["Department"] == "CSE")]

print(result)
# Out:
#     Student_ID        Name  Age Department  Marks
# 7            8   Student_8   22        CSE     93
# 13          14  Student_14   20        CSE     88
# 21          22  Student_22   22        CSE     88
# 23          24  Student_24   25        CSE     88
# 24          25  Student_25   21        CSE     95
# 31          32  Student_32   18        CSE     93
# 47          48  Student_48   24        CSE     94
# 55          56  Student_56   21        CSE     91

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("students.csv")

df.loc[5, "Marks"] = np.nan
df.loc[20, "Age"] = np.nan

print("Before Cleaning")
print(df.isnull().sum())

df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
df["Age"] = df["Age"].fillna(df["Age"].mean())

print("After Cleaning")
print(df.isnull().sum())
# Out:
# Before Cleaning
# Student_ID    0
# Name          0
# Age           1
# Department    0
# Marks         1
# dtype: int64
# After Cleaning
# Student_ID    0
# Name          0
# Age           0
# Department    0
# Marks         0
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("students.csv")

df.to_excel("students.xlsx", index=False)
df.to_json("students.json")

print("Files Exported Successfully")
# Out:
# Files Exported Successfully
